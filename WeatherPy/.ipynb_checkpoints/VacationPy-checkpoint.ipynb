# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import numpy as np

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0      atafu village  -8.5421 -172.5159     26.05        89
# 1        1  port-aux-francais -49.3500   70.2167      6.10        93
# 2        2         isafjordur  66.0755  -23.1240      6.02        70
# 3        3           polewali  -3.4324  119.3435     28.92        81
# 4        4           gisborne -38.6533  178.0042     12.33        78
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.69      TK  1702452748
# 1          99        8.99      TF  1702452748
# 2         100        3.60      IS  1702452750
# 3          80        0.54      ID  1702452750
# 4         100        1.10      NZ  1702452750

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_cities = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    color = "City"
)

# Display the map
map_cities
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df[(city_data_df["Max Temp"]<=27) & 
                            (city_data_df["Max Temp"]>=15) &
                                (city_data_df["Wind Speed"]<=4.5) &
                                   (city_data_df["Cloudiness"]==0)]

# Display sample data
ideal_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 14        14         imperatriz  -5.5264  -47.4917     25.03       100
# 43        43           protaras  35.0125   34.0583     18.95        72
# 73        73       kruisfontein -34.0033   24.7314     19.94        49
# 79        79    arraial do cabo -22.9661  -42.0278     22.03        76
# 82        82        sao vicente -23.9631  -46.3919     22.93        26
# 292      292  sao joao da barra -21.6403  -41.0511     20.79        89
# 329      329             waddan  29.1614   16.1390     17.06        34
# 339      339        basse-terre  16.1667  -61.6667     22.55        88
# 348      348              pisco -13.7000  -76.2167     20.03        83
# 411      411           holualoa  19.6228 -155.9522     22.91        78
# 439      439          vredendal -31.6683   18.5012     22.43        38
# 456      456        kailua-kona  19.6406 -155.9956     24.98        78
# 470      470       keetmanshoop -26.5833   18.1333     25.51        27
# 475      475            guaruja -23.9931  -46.2564     19.94        26
# 512      512         uttarkashi  30.7333   78.4500     17.28        24
# 514      514       general pico -35.6566  -63.7568     17.29        92
# 525      525             de aar -30.6497   24.0123     23.28        33
# 535      535     guerrero negro  27.9769 -114.0611     16.31        74
#
#      Cloudiness  Wind Speed Country        Date
# 14            0        1.03      BR  1702452752
# 43            0        0.45      CY  1702452757
# 73            0        3.58      ZA  1702452762
# 79            0        2.05      BR  1702452763
# 82            0        1.25      BR  1702452764
# 292           0        2.77      BR  1702452803
# 329           0        1.51      LY  1702452812
# 339           0        1.03      GP  1702452815
# 348           0        3.09      PE  1702452758
# 411           0        2.57      US  1702452828
# 439           0        0.70      ZA  1702452835
# 456           0        2.57      US  1702452571
# 470           0        0.51     NaN  1702452839
# 475           0        1.27      BR  1702452840
# 512           0        2.56      IN  1702452847
# 514           0        4.04      AR  1702452848
# 525           0        3.28      ZA  1702452850
# 535           0        2.25      MX  1702452852

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[["City", "Lat", "Lng", "Country", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df.insert(5,"Hotel Name", "")

# Display sample data
hotel_df
# Out:
#                   City      Lat       Lng Country  Humidity Hotel Name
# 14          imperatriz  -5.5264  -47.4917      BR       100
# 43            protaras  35.0125   34.0583      CY        72
# 73        kruisfontein -34.0033   24.7314      ZA        49
# 79     arraial do cabo -22.9661  -42.0278      BR        76
# 82         sao vicente -23.9631  -46.3919      BR        26
# 292  sao joao da barra -21.6403  -41.0511      BR        89
# 329             waddan  29.1614   16.1390      LY        34
# 339        basse-terre  16.1667  -61.6667      GP        88
# 348              pisco -13.7000  -76.2167      PE        83
# 411           holualoa  19.6228 -155.9522      US        78
# 439          vredendal -31.6683   18.5012      ZA        38
# 456        kailua-kona  19.6406 -155.9956      US        78
# 470       keetmanshoop -26.5833   18.1333     NaN        27
# 475            guaruja -23.9931  -46.2564      BR        26
# 512         uttarkashi  30.7333   78.4500      IN        24
# 514       general pico -35.6566  -63.7568      AR        92
# 525             de aar -30.6497   24.0123      ZA        33
# 535     guerrero negro  27.9769 -114.0611      MX        74

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey":geoapify_key 
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# imperatriz - nearest hotel: Hotel Posseidon
# protaras - nearest hotel: Capo Bay
# kruisfontein - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# sao vicente - nearest hotel: Pousada Vitória
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# waddan - nearest hotel: No hotel found
# basse-terre - nearest hotel: Le Créoliles
# pisco - nearest hotel: La Portada
# holualoa - nearest hotel: Kona Hotel
# vredendal - nearest hotel: No hotel found
# kailua-kona - nearest hotel: Kona Seaside Hotel
# keetmanshoop - nearest hotel: Canyon Hotel
# guaruja - nearest hotel: Ferrareto Hotel
# uttarkashi - nearest hotel: Shivalinga
# general pico - nearest hotel: Euskadi Hotel
# de aar - nearest hotel: No hotel found
# guerrero negro - nearest hotel: Plaza sal paraiso
#                   City      Lat       Lng Country  Humidity  \
# 14          imperatriz  -5.5264  -47.4917      BR       100
# 43            protaras  35.0125   34.0583      CY        72
# 73        kruisfontein -34.0033   24.7314      ZA        49
# 79     arraial do cabo -22.9661  -42.0278      BR        76
# 82         sao vicente -23.9631  -46.3919      BR        26
# 292  sao joao da barra -21.6403  -41.0511      BR        89
# 329             waddan  29.1614   16.1390      LY        34
# 339        basse-terre  16.1667  -61.6667      GP        88
# 348              pisco -13.7000  -76.2167      PE        83
# 411           holualoa  19.6228 -155.9522      US        78
# 439          vredendal -31.6683   18.5012      ZA        38
# 456        kailua-kona  19.6406 -155.9956      US        78
# 470       keetmanshoop -26.5833   18.1333     NaN        27
# 475            guaruja -23.9931  -46.2564      BR        26
# 512         uttarkashi  30.7333   78.4500      IN        24
# 514       general pico -35.6566  -63.7568      AR        92
# 525             de aar -30.6497   24.0123      ZA        33
# 535     guerrero negro  27.9769 -114.0611      MX        74
#
#                Hotel Name
# 14        Hotel Posseidon
# 43               Capo Bay
# 73         No hotel found
# 79         No hotel found
# 82        Pousada Vitória
# 292  Pousada Mediterrâneo
# 329        No hotel found
# 339          Le Créoliles
# 348            La Portada
# 411            Kona Hotel
# 439        No hotel found
# 456    Kona Seaside Hotel
# 470          Canyon Hotel
# 475       Ferrareto Hotel
# 512            Shivalinga
# 514         Euskadi Hotel
# 525        No hotel found
# 535     Plaza sal paraiso

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_hotel = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "City",
    scale = 1.5,
    size = "Humidity",
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
map_hotel
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
