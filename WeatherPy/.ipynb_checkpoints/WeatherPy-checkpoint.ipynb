# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Set the Temperature Unit to Metric
units = "metric"

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 568

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | cockburn town
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | yelovo
# Processing Record 6 of Set 1 | port mathurin
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | el granada
# Processing Record 9 of Set 1 | vorgashor
# Processing Record 10 of Set 1 | san andros
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto natales
# Processing Record 12 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 1 | susuman
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | hadibu
# Processing Record 17 of Set 1 | stanley
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | utrik
# Processing Record 21 of Set 1 | wailua homesteads
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | whitehorse
# Processing Record 24 of Set 1 | nishinoomote
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | waitangi
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | invercargill
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | isafjordur
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | polyarnyy
# Processing Record 34 of Set 1 | myeik
# Processing Record 35 of Set 1 | benguela
# Processing Record 36 of Set 1 | tahoua
# Processing Record 37 of Set 1 | adamstown
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | hawaiian paradise park
# Processing Record 40 of Set 1 | howard springs
# Processing Record 41 of Set 1 | mamuju
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | byron bay
# Processing Record 44 of Set 1 | boende
# Processing Record 45 of Set 1 | papatowai
# Processing Record 46 of Set 1 | hotan
# Processing Record 47 of Set 1 | ta`u
# Processing Record 48 of Set 1 | fort bragg
# Processing Record 49 of Set 1 | blackmans bay
# Processing Record 50 of Set 1 | udachny
# Processing Record 0 of Set 2 | al majaridah
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | lerwick
# Processing Record 3 of Set 2 | keflavik
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | galliano
# Processing Record 6 of Set 2 | mount pearl
# Processing Record 7 of Set 2 | saipan
# Processing Record 8 of Set 2 | gwadar
# Processing Record 9 of Set 2 | margate
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | tralee
# Processing Record 12 of Set 2 | kamaishi
# Processing Record 13 of Set 2 | sault ste. marie
# Processing Record 14 of Set 2 | samsun
# Processing Record 15 of Set 2 | kapuskasing
# Processing Record 16 of Set 2 | sinan
# Processing Record 17 of Set 2 | khovd
# City not found. Skipping...
# Processing Record 6 of Set 5 | warrnambool
# Processing Record 7 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 8 of Set 5 | dudinka
# Processing Record 9 of Set 5 | weno
# Processing Record 10 of Set 5 | corner brook
# Processing Record 11 of Set 5 | port blair
# Processing Record 12 of Set 5 | new norfolk
# Processing Record 13 of Set 5 | nadi
# Processing Record 14 of Set 5 | neiafu
# Processing Record 15 of Set 5 | san jose del cabo
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | atafu village
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | hamilton
# Processing Record 20 of Set 5 | sydney mines
# Processing Record 21 of Set 5 | acapulco de juarez
# Processing Record 22 of Set 5 | hudiksvall
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 25 of Set 5 | isla mujeres
# Processing Record 26 of Set 5 | de aar
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | kogalym
# Processing Record 29 of Set 5 | chonchi
# Processing Record 30 of Set 5 | brookings
# Processing Record 31 of Set 5 | ust-nera
# Processing Record 32 of Set 5 | alo
# Processing Record 33 of Set 5 | hoxtolgay
# City not found. Skipping...
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | zavidovo
# Processing Record 36 of Set 5 | sekong
# Processing Record 37 of Set 5 | ipinda
# Processing Record 38 of Set 5 | mcalester
# Processing Record 39 of Set 5 | nemuro
# Processing Record 40 of Set 5 | igarka
# Processing Record 41 of Set 5 | guerrero negro
# Processing Record 42 of Set 5 | siparia
# Processing Record 43 of Set 5 | selfoss
# Processing Record 44 of Set 5 | fada
# Processing Record 45 of Set 5 | hammerfest
# Processing Record 46 of Set 5 | suchedniow
# Processing Record 47 of Set 5 | kavaratti
# Processing Record 48 of Set 5 | mulchen
# Processing Record 49 of Set 5 | olinda
# Processing Record 0 of Set 6 | bayan nur
# City not found. Skipping...
# Processing Record 1 of Set 6 | akrehamn
# Processing Record 2 of Set 6 | ares
# Processing Record 3 of Set 6 | oranjemund
# Processing Record 4 of Set 6 | nolinsk
# Processing Record 5 of Set 6 | madimba
# Processing Record 6 of Set 6 | mikuni
# Processing Record 7 of Set 6 | saint-pierre
# Processing Record 8 of Set 6 | illizi
# Processing Record 9 of Set 6 | aasiaat
# Processing Record 10 of Set 6 | vanimo
# Processing Record 11 of Set 6 | deqen
# Processing Record 12 of Set 6 | bel ombre
# Processing Record 13 of Set 6 | choix
# Processing Record 14 of Set 6 | at taj
# Processing Record 15 of Set 6 | miracema do tocantins
# Processing Record 16 of Set 6 | kalawit
# Processing Record 17 of Set 6 | nieuw amsterdam
# Processing Record 18 of Set 6 | mbandaka
# Processing Record 19 of Set 6 | qaqortoq
# Processing Record 20 of Set 6 | puerto baquerizo moreno
# Processing Record 21 of Set 6 | hultsfred
# Processing Record 22 of Set 6 | maslyanino
# Processing Record 23 of Set 6 | tazovsky
# Processing Record 24 of Set 6 | gherla
# Processing Record 25 of Set 6 | glace bay
# Processing Record 26 of Set 6 | pangody
# Processing Record 27 of Set 6 | laayoune
# Processing Record 28 of Set 6 | plastun
# Processing Record 29 of Set 6 | tolanaro
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | mayna
# Processing Record 32 of Set 6 | ocean city
# Processing Record 33 of Set 6 | kalmunai
# Processing Record 34 of Set 6 | lazaro cardenas
# Processing Record 35 of Set 6 | chiras
# Processing Record 36 of Set 6 | quthing
# Processing Record 37 of Set 6 | ar rutbah
# Processing Record 38 of Set 6 | chui
# Processing Record 39 of Set 6 | patterson
# Processing Record 40 of Set 6 | mazagao
# Processing Record 41 of Set 6 | lubao
# Processing Record 42 of Set 6 | nar'yan-mar
# Processing Record 43 of Set 6 | villa gesell
# Processing Record 44 of Set 6 | spring creek
# Processing Record 45 of Set 6 | santiago de cuba
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | retiro
# Processing Record 48 of Set 6 | big rapids
# Processing Record 49 of Set 6 | nuuk
# Processing Record 0 of Set 7 | magadi
# Processing Record 1 of Set 7 | onguday
# Processing Record 2 of Set 7 | yichun
# Processing Record 3 of Set 7 | laojunmiao
# Processing Record 4 of Set 7 | la sarre
# Processing Record 5 of Set 7 | kimbe
# Processing Record 6 of Set 7 | yelizovo
# Processing Record 7 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 8 of Set 7 | la foa
# Processing Record 9 of Set 7 | caibarien
# Processing Record 10 of Set 7 | gilgit
# Processing Record 11 of Set 7 | maintirano
# Processing Record 12 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 13 of Set 7 | waingapu
# Processing Record 14 of Set 7 | revda
# Processing Record 15 of Set 7 | kismayo
# Processing Record 16 of Set 7 | yeppoon
# Processing Record 17 of Set 7 | horta
# Processing Record 18 of Set 7 | vorkuta
# Processing Record 19 of Set 7 | baranovichi
# Processing Record 20 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 21 of Set 7 | sao luiz gonzaga
# Processing Record 22 of Set 7 | loukhi
# Processing Record 23 of Set 7 | san lorenzo
# Processing Record 24 of Set 7 | dryden
# Processing Record 25 of Set 7 | kavieng
# Processing Record 26 of Set 7 | charters towers
# Processing Record 27 of Set 7 | ancud
# Processing Record 28 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 29 of Set 7 | howrah
# Processing Record 30 of Set 7 | kuqa
# Processing Record 31 of Set 7 | freetown
# Processing Record 32 of Set 7 | ketchikan
# Processing Record 33 of Set 7 | lepsy
# Processing Record 34 of Set 7 | shache
# Processing Record 35 of Set 7 | nadym
# Processing Record 36 of Set 7 | mugia
# Processing Record 37 of Set 7 | nyagan
# Processing Record 38 of Set 7 | hermanus
# Processing Record 39 of Set 7 | vila velha
# Processing Record 40 of Set 7 | urangan
# Processing Record 41 of Set 7 | kampene
# Processing Record 11 of Set 9 | kidal
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | walvis bay
# Processing Record 14 of Set 9 | almeirim
# Processing Record 15 of Set 9 | askoy
# Processing Record 16 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 17 of Set 9 | geraldton
# Processing Record 18 of Set 9 | fagaras
# Processing Record 19 of Set 9 | fort mcmurray
# Processing Record 20 of Set 9 | mount isa
# Processing Record 21 of Set 9 | san rafael del yuma
# Processing Record 22 of Set 9 | nakuru
# Processing Record 23 of Set 9 | ankang
# Processing Record 24 of Set 9 | namyang
# Processing Record 25 of Set 9 | boca suno
# Processing Record 26 of Set 9 | flying fish cove
# Processing Record 27 of Set 9 | anloga
# Processing Record 28 of Set 9 | miquelon
# Processing Record 29 of Set 9 | santa cruz
# Processing Record 30 of Set 9 | zhalantun
# Processing Record 31 of Set 9 | mahina
# Processing Record 32 of Set 9 | fannuj
# City not found. Skipping...
# Processing Record 33 of Set 9 | tapiramuta
# Processing Record 34 of Set 9 | kultali
# City not found. Skipping...
# Processing Record 35 of Set 9 | morro bay
# Processing Record 36 of Set 9 | vilyuysk
# Processing Record 37 of Set 9 | okha
# Processing Record 38 of Set 9 | dhidhdhoo
# Processing Record 39 of Set 9 | ola
# Processing Record 40 of Set 9 | ko samui
# Processing Record 41 of Set 9 | katsuura
# Processing Record 42 of Set 9 | piti village
# Processing Record 43 of Set 9 | barentu
# Processing Record 44 of Set 9 | isla vista
# Processing Record 45 of Set 9 | amahai
# Processing Record 46 of Set 9 | saint-joseph
# Processing Record 47 of Set 9 | calama
# Processing Record 48 of Set 9 | segezha
# Processing Record 49 of Set 9 | kota tinggi
# Processing Record 0 of Set 10 | altai
# Processing Record 1 of Set 10 | tubarjal
# Processing Record 2 of Set 10 | ghat
# Processing Record 3 of Set 10 | rikaze
# Processing Record 4 of Set 10 | savaneta
# Processing Record 5 of Set 10 | boone
# Processing Record 6 of Set 10 | tanout
# Processing Record 7 of Set 10 | morehead city
# Processing Record 8 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 9 of Set 10 | panacan
# Processing Record 10 of Set 10 | malango
# Processing Record 11 of Set 10 | sena madureira
# Processing Record 12 of Set 10 | gueugnon
# Processing Record 13 of Set 10 | coquimbo
# Processing Record 14 of Set 10 | huanggang
# Processing Record 15 of Set 10 | bloomfield
# Processing Record 16 of Set 10 | yarmouth
# Processing Record 17 of Set 10 | dalandzadgad
# Processing Record 18 of Set 10 | melendugno
# Processing Record 19 of Set 10 | derbent
# Processing Record 20 of Set 10 | neman
# Processing Record 21 of Set 10 | mawu
# Processing Record 22 of Set 10 | fort stockton
# Processing Record 23 of Set 10 | kristiansund
# Processing Record 24 of Set 10 | jatibonico
# Processing Record 25 of Set 10 | pionerskiy
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | bereket
# Processing Record 28 of Set 10 | tofol
# Processing Record 29 of Set 10 | soe
# Processing Record 30 of Set 10 | xilin hot
# Processing Record 31 of Set 10 | tual
# Processing Record 32 of Set 10 | kegeyli shahar
# Processing Record 33 of Set 10 | dierkow-neu
# City not found. Skipping...
# Processing Record 34 of Set 10 | villazon
# Processing Record 35 of Set 10 | torghay
# Processing Record 36 of Set 10 | galle
# Processing Record 37 of Set 10 | tonekabon
# Processing Record 38 of Set 10 | san ignacio de velasco
# Processing Record 39 of Set 10 | tibanbang
# Processing Record 40 of Set 10 | scarborough
# Processing Record 41 of Set 10 | molde
# Processing Record 42 of Set 10 | khandyga
# Processing Record 43 of Set 10 | sandnessjoen
# Processing Record 44 of Set 10 | attapeu
# Processing Record 45 of Set 10 | egilsstadir
# Processing Record 46 of Set 10 | bikenibeu village
# Processing Record 47 of Set 10 | acajutla
# Processing Record 48 of Set 10 | ormara
# Processing Record 49 of Set 10 | bubaque
# Processing Record 0 of Set 11 | tadmur
# Processing Record 1 of Set 11 | barakani
# Processing Record 2 of Set 11 | deogarh
# Processing Record 3 of Set 11 | masaka
# Processing Record 4 of Set 11 | jovellanos
# Processing Record 5 of Set 11 | gisborne
# Processing Record 6 of Set 11 | newport
# Processing Record 7 of Set 11 | cidade velha
# Processing Record 8 of Set 11 | luang namtha
# Processing Record 9 of Set 11 | padang
# Processing Record 10 of Set 11 | muli
# Processing Record 11 of Set 11 | tindouf
# Processing Record 12 of Set 11 | antofagasta
# Processing Record 13 of Set 11 | kerikeri
# Processing Record 14 of Set 11 | mariental
# Processing Record 15 of Set 11 | akureyri
# Processing Record 16 of Set 11 | wellington
# Processing Record 17 of Set 11 | gazli
# Processing Record 18 of Set 11 | balabac
# Processing Record 19 of Set 11 | kani keli
# Processing Record 20 of Set 11 | ishigaki
# Processing Record 21 of Set 11 | tabas
# Processing Record 22 of Set 11 | st. john's
# Processing Record 23 of Set 11 | port alfred
# Processing Record 24 of Set 11 | felipe carrillo puerto
# Processing Record 25 of Set 11 | poxoreo
# Processing Record 26 of Set 11 | swakopmund
# Processing Record 27 of Set 11 | taichung
# Processing Record 28 of Set 11 | bowen
# Processing Record 29 of Set 11 | kourou
# Processing Record 30 of Set 11 | enewetak
# Processing Record 31 of Set 11 | grand-bassam
# Processing Record 32 of Set 11 | cabedelo
# Processing Record 33 of Set 11 | gniew
# Processing Record 34 of Set 11 | dadonghai
# City not found. Skipping...
# Processing Record 35 of Set 11 | keetmanshoop
# Processing Record 36 of Set 11 | umea
# Processing Record 37 of Set 11 | cholpon-ata
# Processing Record 38 of Set 11 | summerside
# Processing Record 39 of Set 11 | bontang
# Processing Record 40 of Set 11 | manacapuru
# Processing Record 41 of Set 11 | lobatse
# Processing Record 42 of Set 11 | kizel
# Processing Record 43 of Set 11 | esquel
# Processing Record 44 of Set 11 | boguchany
# Processing Record 45 of Set 11 | castillos
# Processing Record 46 of Set 11 | kasongo-lunda
# Processing Record 47 of Set 11 | manado
# Processing Record 48 of Set 11 | visby
# Processing Record 49 of Set 11 | kirakira
# Processing Record 0 of Set 12 | savur
# Processing Record 1 of Set 12 | manokwari
# Processing Record 2 of Set 12 | umm kaddadah
# Processing Record 3 of Set 12 | kurumkan
# Processing Record 4 of Set 12 | persembe
# Processing Record 5 of Set 12 | al fuwayliq
# Processing Record 6 of Set 12 | dzhambeyty
# Processing Record 7 of Set 12 | tosontsengel
# Processing Record 8 of Set 12 | acarau
# Processing Record 9 of Set 12 | colares
# Processing Record 10 of Set 12 | nabire
# Processing Record 11 of Set 12 | sausset-les-pins
# Processing Record 12 of Set 12 | san fernando
# Processing Record 13 of Set 12 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | wenshui
# Processing Record 15 of Set 12 | recani
# Processing Record 16 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 17 of Set 12 | hilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         avarua -21.2078 -159.7750     25.03        83         100
# 1  cockburn town  21.4612  -71.1419     26.45        80          83
# 2  mar del plata -38.0023  -57.5575     19.41        89           0
# 3          tiksi  71.6872  128.8694    -20.76       100         100
# 4         yelovo  57.0538   54.9207    -25.12        79          96
#
#    Wind Speed Country        Date
# 0        9.26      CK  1702360067
# 1        9.38      TC  1702360067
# 2        5.36      AR  1702360067
# 3        3.60      RU  1702360068
# 4        5.45      RU  1702360068

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               avarua -21.2078 -159.7750     25.03        83         100
# 1        cockburn town  21.4612  -71.1419     26.45        80          83
# 2        mar del plata -38.0023  -57.5575     19.41        89           0
# 3                tiksi  71.6872  128.8694    -20.76       100         100
# 4               yelovo  57.0538   54.9207    -25.12        79          96
#
#          Wind Speed Country        Date
# City_ID
# 0              9.26      CK  1702360067
# 1              9.38      TC  1702360067
# 2              5.36      AR  1702360067
# 3              3.60      RU  1702360068
# 4              5.45      RU  1702360068

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity in World Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(y_axis)
    plt.title(fig_title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        cockburn town  21.4612  -71.1419     26.45        80          83
# 3                tiksi  71.6872  128.8694    -20.76       100         100
# 4               yelovo  57.0538   54.9207    -25.12        79          96
# 6          yellowknife  62.4560 -114.3525    -24.21        92          75
# 7           el granada  37.5027 -122.4694     13.53        93         100
#
#          Wind Speed Country        Date
# City_ID
# 1              9.38      TC  1702360067
# 3              3.60      RU  1702360068
# 4              5.45      RU  1702360068
# 6              3.09      CA  1702359942
# 7              3.60      US  1702360068

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                             avarua -21.2078 -159.7750     25.03        83
# 2                      mar del plata -38.0023  -57.5575     19.41        89
# 5                      port mathurin -19.6833   63.4167     26.27        74
# 9                     puerto natales -51.7236  -72.4875      5.29        90
# 11       edinburgh of the seven seas -37.0676  -12.3116     14.64        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        9.26      CK  1702360067
# 2                 0        5.36      AR  1702360067
# 5                15        5.75      MU  1702360068
# 9                81        3.98      CL  1702360068
# 11              100       11.16      SH  1702360068

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
y_axis = "Temperature (Celsius)"
fig_title = "Temperatures in the Northern Hemisphere"
coordinates = (35,25)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.7287519838138021

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
y_axis = "Temperature (Celsius)"
fig_title = "Temperatures in the Southern Hemisphere"
coordinates = (-30,10)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.41215672608422005

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be a positive correlation between latitudes and maximum temperatures in the Southern Hemisphere, while the opposite applies to the Northern Hemisphere latitudes and their respective temperatures (a negative correlation).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
y_axis = "Humidity"
fig_title = "Humidity in the Northern Hemisphere"
coordinates = (45,40)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.14424359662287373

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
y_axis = "Humidity"
fig_title = "Humidity in the Southern Hemisphere"
coordinates = (-50,40)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.04361868128199677

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be a slightly more positive correlation between latitudes and humidity levels in the Northern Hemisphere than the correlation in the Souther Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
y_axis = "Cloudiness"
fig_title = "Cloudiness in the Northern Hemisphere"
coordinates = (40,50)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.09294541317923777

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
y_axis = "Cloudiness"
fig_title = "Cloudiness in the Southern Hemisphere"
coordinates = (-50,55)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.04703959725705708

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be a slightly more positive correlation between latitudes and cloudiness in the Northern Hemisphere than the correlation in the Southern Hemisphere. However, the difference in correlation between the hemispheres is almost negligible.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
y_axis = "Wind Speed"
fig_title = "Wind Speed in the Northern Hemisphere"
coordinates = (10,10)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.006008065337094348

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
y_axis = "Wind Speed"
fig_title = "Wind Speed in the Southern Hemisphere"
coordinates = (-25,6)
plot_linear_regression(x_values, y_values, y_axis, coordinates, fig_title)
# Out:
# The r-value is: 0.07872614358703392

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be a very small positive (almost zero) correlation between latitudes and wind speed in the Northern Hemipshere, whereas the correlation in the Southern Hemisphere is also small but negative.
